# %%
from ddpm.model import DDPM

# %%
ddpm_model = DDPM()

# %%
ddpm_model.sample()
# Out:
# Min: -4.407891273498535, Max: 4.370100498199463
# Iteration: 0 ; Discrete time: 999
# <PIL.Image.Image image mode=RGB size=256x512>
# Min: -4.365667343139648, Max: 4.269622325897217
# Min: -4.420057773590088, Max: 4.457664489746094
# Min: -4.4321770668029785, Max: 4.5783233642578125
# Min: -4.501592636108398, Max: 4.764571189880371
# Min: -4.388120651245117, Max: 4.899681091308594
# Min: -4.37059211730957, Max: 4.881937503814697
# Min: -4.274871349334717, Max: 4.544641494750977
# Min: -4.3336076736450195, Max: 4.433962821960449
# Min: -4.367011070251465, Max: 4.381615161895752
# Min: -4.416876792907715, Max: 4.297750473022461
# Min: -4.223941802978516, Max: 4.387651443481445
# Min: -4.197582721710205, Max: 4.214211463928223
# Min: -4.305157661437988, Max: 4.256863594055176
# Min: -4.231210231781006, Max: 4.170285224914551
# Min: -4.431106090545654, Max: 4.107583999633789
# Min: -4.561091423034668, Max: 4.084814548492432
# Min: -4.403197288513184, Max: 4.043026447296143
# ...

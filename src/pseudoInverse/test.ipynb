# %%
from PIL import Image

# %%
path = "../ffhq256-1k-validation/00000.png"
image = Image.open(path)

# %%
from algorithm import example_usage
result = example_usage(image)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 from algorithm import example_usage
#       3 result = example_usage(image)
#
# File c:\Users\Mrabe\OneDrive\Bureau\cours MVA\Generative Models\project\PiGDM\src\pseudoInverse\algorithm.py:10
#       6 import sys
#       7 sys.path.append(r"C:\Users\Mrabe\OneDrive\Bureau\cours MVA\Generative Models\project\PiGDM\src")
# ---> 10 from src.ddpm.model import DDPM
#      12 def pigdm_sampling(
#      13     y,                      # Measurement/observation
#      14     eps_model,              # Epsilon prediction model
#    (...)
#      21     seed=None               # Random seed for reproducibility
#      22 ):
#      23     """
#      24     Implementation of the PiGDM (Pseudoinverse Guided Diffusion Model) sampling algorithm.
#      25
#    (...)
#      38         The sampled image/data
# ...
